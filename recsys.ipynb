# %%
import pandas as pd
import numpy as np
from surprise import Reader, Dataset, SVD
from collections import defaultdict
from tqdm import tqdm
from surprise.model_selection import cross_validate, train_test_split
from scipy.sparse import csr_matrix

# %%
train = pd.read_csv('recsys_music_vk/train.csv')
train
# Out:
#                       userId                   id             artistId
# 0       -9223365420690745920  4789011704403477758  4862000404086590321
# 1       -9223357012432074795 -3685301030413601284 -5911062739952260612
# 2       -9223357012432074795 -1040959798245656474  6738173673409941080
# 3       -9223331337535253792 -8750332497321603794 -2531033142411854446
# 4       -9223331337535253792  7353026449734842135  -285672225852509948
# ...                      ...                  ...                  ...
# 4920099  9223323429584020370 -6973328648673682165 -3904789406522786641
# 4920100  9223323429584020370  3712711740551503640 -3690361587617342969
# 4920101  9223341540783520542  8309155247938420417 -7126264979390954459
# 4920102  9223351321092564051 -3093196378698218885  5622172636319693268
# 4920103  9223371011342822842 -5980201165290333063  1561191507488961909
#
# [4920104 rows x 3 columns]

# %%
train = train[['userId', 'id']]

# %%
train
# Out:
#                       userId                   id
# 0       -9223365420690745920  4789011704403477758
# 1       -9223357012432074795 -3685301030413601284
# 2       -9223357012432074795 -1040959798245656474
# 3       -9223331337535253792 -8750332497321603794
# 4       -9223331337535253792  7353026449734842135
# ...                      ...                  ...
# 4920099  9223323429584020370 -6973328648673682165
# 4920100  9223323429584020370  3712711740551503640
# 4920101  9223341540783520542  8309155247938420417
# 4920102  9223351321092564051 -3093196378698218885
# 4920103  9223371011342822842 -5980201165290333063
#
# [4920104 rows x 2 columns]

# %%
train['weight'] = 1

# %%
users_train = set(train['userId'])
user2idx = {u: i for i, u in enumerate(users_train)}
idx2user = {i: u for i, u in enumerate(users_train)}

# %%
items_train = set(train['id'])
item2idx = {u: i for i, u in enumerate(items_train)}
idx2item = {i: u for i, u in enumerate(items_train)}

# %%
train['userId'] = train['userId'].map(user2idx)

# %%
train['id'] = train['id'].map(item2idx)

# %%
train
# Out:
#           userId      id  weight
# 0         996772  162886       1
# 1          28477  333755       1
# 2          28477  530506       1
# 3        1005410  448394       1
# 4        1005410  613949       1
# ...          ...     ...     ...
# 4920099   169265    2268       1
# 4920100   169265  602521       1
# 4920101    54069  339306       1
# 4920102   953224  216939       1
# 4920103   927373  592317       1
#
# [4920104 rows x 3 columns]

# %%
(len(users_train), len(items_train))
# Out:
# (1166360, 629330)

# %%
train.astype(pd.SparseDtype("float", np.nan))
# Out:
#             userId        id  weight
# 0         996772.0  162886.0     1.0
# 1          28477.0  333755.0     1.0
# 2          28477.0  530506.0     1.0
# 3        1005410.0  448394.0     1.0
# 4        1005410.0  613949.0     1.0
# ...            ...       ...     ...
# 4920099   169265.0    2268.0     1.0
# 4920100   169265.0  602521.0     1.0
# 4920101    54069.0  339306.0     1.0
# 4920102   953224.0  216939.0     1.0
# 4920103   927373.0  592317.0     1.0
#
# [4920104 rows x 3 columns]

# %%
mtx = csr_matrix(train[['userId', 'id']])

# %%
mtx = csr_matrix((train['weight'], (train['userId'], train['id'])), shape=(len(users_train), len(items_train)))

# %%
np.array().

# %%
train['userId'].value_counts()
# Out:
# userId
# 1161472    12413
# 1002670     7957
# 950641      4559
# 249489      4404
# 662254      4354
#            ...
# 491074         1
# 858902         1
# 490823         1
# 413406         1
# 927373         1
# Name: count, Length: 1166360, dtype: int64

# %%
mtx[1161472].toarray().tolist()[0].count(1)
# Out:
# 12413

# %%
import matplotlib.pyplot as plt
from scipy.sparse import coo_matrix

def plot_coo_matrix(m):
    if not isinstance(m, coo_matrix):
        m = coo_matrix(m)
    fig = plt.figure()
    ax = fig.add_subplot(111, facecolor='black')
    ax.plot(m.col, m.row, 's', color='white', ms=1)
    ax.set_xlim(0, m.shape[1])
    ax.set_ylim(0, m.shape[0])
    ax.set_aspect('equal')
    for spine in ax.spines.values():
        spine.set_visible(False)
    ax.invert_yaxis()
    ax.set_aspect('equal')
    ax.set_xticks([])
    ax.set_yticks([])
    return ax

# %%
train.columns = ['userId:token', 'id:token', 'artistId:token']

# %%
train['timestamp:float'] = range(len(train))

# %%
train[['userId:token', 'id:token', 'timestamp:float']].to_csv('recsys_music_vk/recbole/vk.csv', index=False)

# %%
gb = train[['id:token', 'artistId:token']].groupby('id:token').agg(pd.Series.mode)

# %%
gb.reset_index()['id:token'].value_counts()
# Out:
# id:token
# -9223319875987156276    1
#  3078715584218385455    1
#  3078557274697066264    1
#  3078567090825961540    1
#  3078574230345570405    1
#                        ..
# -3080689036666377598    1
# -3080685305053056212    1
# -3080642327310137654    1
# -3080641383902613352    1
#  9223353768117050793    1
# Name: count, Length: 629330, dtype: int64

# %%
from recbole.quick_start import run_recbole
# Out:
# 2025-02-11 16:54:16.984940: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
run_recbole(model='Pop', dataset='vk', 
           config_file_list=['recsys_music_vk/recbole/vk/config.yaml']
           )
# Out:
# 11 Feb 18:06    INFO  ['/home/xbar19/ML/MLEnv/lib/python3.10/site-packages/ipykernel_launcher.py', '-f', '/home/xbar19/.local/share/jupyter/runtime/kernel-bff4fdc4-3b5d-433b-95ff-cb3e4fbb6560.json']
# 11 Feb 18:06    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recsys_music_vk/recbole/vk
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 3
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.19, 0.01]}, 'order': 'TO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [3]
# valid_metric = Precision@3
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator = ,
# seq_separator =
# USER_ID_FIELD = userId
# ITEM_ID_FIELD = id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['userId', 'id', 'timestamp'], 'item': ['id', 'authorId']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.TRADITIONAL
# loss_type = BPR
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cuda
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 11 Feb 18:08    WARNING  No columns has been loaded from [FeatureSource.ITEM]
# /home/xbar19/ML/MLEnv/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:648: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=0, inplace=True)
# /home/xbar19/ML/MLEnv/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:650: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=feat[field].mean(), inplace=True)
# 11 Feb 18:09    INFO  vk
# The number of users: 1166361
# Average actions of users: 4.2183408210158095
# The number of items: 629331
# Average actions of items: 7.8180032733224225
# The number of inters: 4920104
# The sparsity of the dataset: 99.99932971088276%
# Remain Fields: ['userId', 'id', 'timestamp']
# 11 Feb 18:09    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 11 Feb 18:09    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.19, 0.01]}, 'order': 'TO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 11 Feb 18:09    INFO  Pop()
# Trainable parameters: 1
# 11 Feb 18:09    INFO  FLOPs: 1
# Train     0:   0%|                                                         | 0/3544 [00:00<?, ?it/s]/home/xbar19/ML/MLEnv/lib/python3.10/site-packages/recbole/trainer/trainer.py:235: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = amp.GradScaler(enabled=self.enable_scaler)
# Train     0:   0%|                                | 0/3544 [00:00<?, ?it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                        | 1/3544 [00:00<31:44,  1.86it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                        | 1/3544 [00:00<31:44,  1.86it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                        | 1/3544 [00:00<31:44,  1.86it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                        | 3/3544 [00:00<10:29,  5.63it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                        | 3/3544 [00:00<10:29,  5.63it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                        | 3/3544 [00:00<10:29,  5.63it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                        | 5/3544 [00:00<06:40,  8.84it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                        | 5/3544 [00:00<06:40,  8.84it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                        | 5/3544 [00:00<06:40,  8.84it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                        | 5/3544 [00:00<06:40,  8.84it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                        | 8/3544 [00:00<04:28, 13.17it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                        | 8/3544 [00:00<04:28, 13.17it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                        | 8/3544 [00:00<04:28, 13.17it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                       | 10/3544 [00:00<04:10, 14.09it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                       | 10/3544 [00:01<04:10, 14.09it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                       | 10/3544 [00:01<04:10, 14.09it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                       | 12/3544 [00:01<03:59, 14.73it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                       | 12/3544 [00:01<03:59, 14.73it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                       | 12/3544 [00:01<03:59, 14.73it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                       | 14/3544 [00:01<03:54, 15.05it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                       | 14/3544 [00:01<03:54, 15.05it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                       | 14/3544 [00:01<03:54, 15.05it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                       | 16/3544 [00:01<03:44, 15.69it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                       | 16/3544 [00:01<03:44, 15.69it/s, GPU RAM: 13.09 G/8.00 G]:   0%|                       | 16/3544 [00:01<03:44, 15.69it/s, GPU RAM: 13.09 G/8.00 G]:   1%|                       | 18/3544 [00:01<03:52, 15.17it/s, GPU RAM: 13.09 G/8.00 G]:   1%|                       | 18/3544 [00:01<03:52, 15.17it/s, GPU RAM: 13.09 G/8.00 G]:   1%|                       | 18/3544 [00:01<03:52, 15.17it/s, GPU RAM: 13.09 G/8.00 G]:   1%|▏                      | 20/3544 [00:01<03:46, 15.56it/s, GPU RAM: 13.09 G/8.00 G]:   1%|▏                      | 20/3544 [00:01<03:46, 15.56it/s, GPU RAM: 13.09 G/8.00 G]:   1%|▏                      | 20/3544 [00:01<03:46, 15.56it/s, GPU RAM: 13.09 G/8.00 G]:   1%|▏                      | 22/3544 [00:01<03:44, 15.70it/s, GPU RAM: 13.09 G/8.00 G]:   1%|▏                      | 22/3544 [00:01<03:44, 15.70it/s, GPU RAM: 13.09 G/8.00 G]:   1%|▏                      | 22/3544 [00:01<03:44, 15.70it/s, GPU RAM: 13.09 G/8.00 G]:   1%|▏                      | 22/3544 [00:01<03:44, 15.70it/s, GPU RAM: 13.09 G/8.00 G]:   1%|▏                      | 25/3544 [00:01<03:15, 17.98it/s, GPU RAM: 13.09 G/8.00 G]:   1%|▏                      | 25/3544 [00:01<03:15, 17.98it/s, GPU RAM: 13.09 G/8.00 G]:   1%|▏                      | 25/3544 [00:01<03:15, 17.98it/s, GPU RAM: 13.09 G/8.00 G]:   1%|▏                      | 25/3544 [00:01<03:15, 17.98it/s, GPU RAM: 13.09 G/8.00 G]:   1%|▏                      | 28/3544 [00:01<02:54, 20.11it/s, GPU RAM: 13.09 G/8.00 G]:   1%|▏                      | 28/3544 [00:02<02:54, 20.11it/s, GPU RAM: 13.09 G/8.00 G]:   1%|▏                      | 28/3544 [00:02<02:54, 20.11it/s, GPU RAM: 13.09 G/8.00 G]:   1%|▏                      | 28/3544 [00:02<02:54, 20.11it/s, GPU RAM: 13.09 G/8.00 G]:   1%|▏                      | 31/3544 [00:02<02:36, 22.38it/s, GPU RAM: ...
#
# KeyboardInterrupt

# %%
gb.to_csv('recsys_music_vk/recbole/vk.csv', index=False)

# %%
train['rating'] = 1

# %%
reader = Reader(rating_scale=(0, 1))

# %%
algo = SVD(n_factors=50)

# %%
ds = Dataset.load_from_df(train[['userId', 'id', 'rating']], reader)

# %%
trainset, testset = train_test_split(ds, test_size=0.2, random_state=42)

# %%
algo.fit(trainset)

# %%
user_listened_tracks = defaultdict(set)
for _, row in tqdm(train.iterrows()):
    user_listened_tracks[row['userId']].add(row['id'])
# Out:
# 4920104it [01:15, 65087.59it/s]

# %%
all_tracks = train['id'].unique()
def get_top_n_recommendations(user_id, n=3):
    # Уберем треки, которые пользователь уже слушал
    unlistened_tracks = [track for track in all_tracks if track not in user_listened_tracks[user_id]]
    # Предскажем рейтинги для непрослушанных треков
    predictions = [algo.predict(user_id, track) for track in unlistened_tracks]
    # Отсортируем предсказания по рейтингу
    predictions.sort(key=lambda x: x.est, reverse=True)
    # Вернем топ-N треков
    return [pred.iid for pred in predictions[:n]]

# %%
pd.read_csv('recsys_music_vk/submission.csv')
# Out:
#                      userId     recommended_id_1     recommended_id_2  \
# 0      -9223331337535253792 -2227263297444998835 -4695036104375440069
# 1      -9223315435871723421 -2227263297444998835 -4695036104375440069
# 2      -9223312953116183861 -2227263297444998835 -4695036104375440069
# 3      -9223189477397287224 -2227263297444998835 -4695036104375440069
# 4      -9223099495950652905 -2227263297444998835 -4695036104375440069
# ...                     ...                  ...                  ...
# 388891  9223205520969697450 -2227263297444998835 -4695036104375440069
# 388892  9223233690124762843 -2227263297444998835 -4695036104375440069
# 388893  9223256937547721480 -2227263297444998835 -4695036104375440069
# 388894  9223293703257417871 -2227263297444998835 -4695036104375440069
# 388895  9223323429584020370 -2227263297444998835 -4695036104375440069
#
#            recommended_id_3
# 0      -8860367773155756475
# 1      -8860367773155756475
# 2      -8860367773155756475
# 3      -8860367773155756475
# 4      -8860367773155756475
# ...                     ...
# 388891 -8860367773155756475
# 388892 -8860367773155756475
# 388893 -8860367773155756475
# 388894 -8860367773155756475
# 388895 -8860367773155756475
#
# [388896 rows x 4 columns]

# %%
submission_users = pd.read_csv('recsys_music_vk/submission.csv')['userId'].unique()

# Генерация рекомендаций для каждого пользователя
# recommendations = []
# for user in tqdm(submission_users):
#     recommended_tracks = get_top_n_recommendations(user, n=3)
#     recommendations.append([user] + recommended_tracks)

# %%
from lightfm import LightFM
from lightfm.data import Dataset
from sklearn.preprocessing import LabelEncoder

# %%
user_encoder = LabelEncoder()
track_encoder = LabelEncoder()
artist_encoder = LabelEncoder()

# Кодируем userId, id и artistId
train['userId'] = user_encoder.fit_transform(train['userId'])
train['id'] = track_encoder.fit_transform(train['id'])
train['artistId'] = artist_encoder.fit_transform(train['artistId'])

# %%
data = train.copy()

# %%
dataset = Dataset()
dataset.fit(users=data['userId'].unique(),
            items=data['id'].unique(),
            item_features=data['artistId'].unique())

# %%
interactions, _ = dataset.build_interactions(zip(data['userId'], data['id']))

# %%
item_features = dataset.build_item_features((x, [y]) for x, y in zip(data['id'], data['artistId']))

# %%
model = LightFM(no_components=50, loss='warp')  # no_components — аналог n_factors в SVD
model.fit(interactions, item_features=item_features, epochs=20, num_threads=4, verbose=True)
# Out:
# Epoch: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [02:26<00:00,  7.33s/it]

# %%
def get_top_n_recommendations(user_id, n=3):
    # Получаем все треки
    all_tracks = data['id'].unique()
    # Предсказываем рейтинги для всех треков
    scores = model.predict(user_id, all_tracks, item_features=item_features)
    # Сортируем треки по убыванию рейтинга
    top_tracks = all_tracks[np.argsort(-scores)]
    # Возвращаем топ-N треков
    return top_tracks[:n]

# %%
import rectools
from rectools.dataset import Dataset
from rectools.dataset.features import DenseFeatures, SparseFeatures, IdMap
from rectools import Columns

# %%
train
# Out:
#                       userId                   id             artistId
# 0       -9223365420690745920  4789011704403477758  4862000404086590321
# 1       -9223357012432074795 -3685301030413601284 -5911062739952260612
# 2       -9223357012432074795 -1040959798245656474  6738173673409941080
# 3       -9223331337535253792 -8750332497321603794 -2531033142411854446
# 4       -9223331337535253792  7353026449734842135  -285672225852509948
# ...                      ...                  ...                  ...
# 4920099  9223323429584020370 -6973328648673682165 -3904789406522786641
# 4920100  9223323429584020370  3712711740551503640 -3690361587617342969
# 4920101  9223341540783520542  8309155247938420417 -7126264979390954459
# 4920102  9223351321092564051 -3093196378698218885  5622172636319693268
# 4920103  9223371011342822842 -5980201165290333063  1561191507488961909
#
# [4920104 rows x 3 columns]

# %%
Columns.User
# Out:
# 'user_id'

# %%
train.columns = [Columns.User, Columns.Item, 'artistId']
train
# Out:
#                      user_id              item_id             artistId
# 0       -9223365420690745920  4789011704403477758  4862000404086590321
# 1       -9223357012432074795 -3685301030413601284 -5911062739952260612
# 2       -9223357012432074795 -1040959798245656474  6738173673409941080
# 3       -9223331337535253792 -8750332497321603794 -2531033142411854446
# 4       -9223331337535253792  7353026449734842135  -285672225852509948
# ...                      ...                  ...                  ...
# 4920099  9223323429584020370 -6973328648673682165 -3904789406522786641
# 4920100  9223323429584020370  3712711740551503640 -3690361587617342969
# 4920101  9223341540783520542  8309155247938420417 -7126264979390954459
# 4920102  9223351321092564051 -3093196378698218885  5622172636319693268
# 4920103  9223371011342822842 -5980201165290333063  1561191507488961909
#
# [4920104 rows x 3 columns]

# %%
idmap = IdMap.from_values(train['item_id'].values)

# %%
train.loc[train['item_id'] == 5070279068330501452]
# Out:
#                      user_id              item_id             artistId
# 283176  -8120145184429995217  5070279068330501452  2383145530433774070
# 2029953 -1636041827672401810  5070279068330501452  5843005928244594932
# 2201188  -989160456579025781  5070279068330501452 -4633425149168328588
# 2360170  -406090589880800750  5070279068330501452  6831642995075930029
# 2842265  1432046587625526532  5070279068330501452  5843005928244594932
# 3922845  5456855360814845806  5070279068330501452  1972603909932029167
# 4245012  6665956668819439866  5070279068330501452  5843005928244594932
# 4888875  9107201330287019163  5070279068330501452  5843005928244594932

# %%
train['item_id'] = train['item_id'].astype(str) + '_' + train['artistId'].astype(str)

# %%
train
# Out:
#                      user_id                                    item_id  \
# 0       -9223365420690745920    4789011704403477758_4862000404086590321
# 1       -9223357012432074795  -3685301030413601284_-5911062739952260612
# 2       -9223357012432074795   -1040959798245656474_6738173673409941080
# 3       -9223331337535253792  -8750332497321603794_-2531033142411854446
# 4       -9223331337535253792    7353026449734842135_-285672225852509948
# ...                      ...                                        ...
# 4920099  9223323429584020370  -6973328648673682165_-3904789406522786641
# 4920100  9223323429584020370   3712711740551503640_-3690361587617342969
# 4920101  9223341540783520542   8309155247938420417_-7126264979390954459
# 4920102  9223351321092564051   -3093196378698218885_5622172636319693268
# 4920103  9223371011342822842   -5980201165290333063_1561191507488961909
#
#                     artistId
# 0        4862000404086590321
# 1       -5911062739952260612
# 2        6738173673409941080
# 3       -2531033142411854446
# 4        -285672225852509948
# ...                      ...
# 4920099 -3904789406522786641
# 4920100 -3690361587617342969
# 4920101 -7126264979390954459
# 4920102  5622172636319693268
# 4920103  1561191507488961909
#
# [4920104 rows x 3 columns]

# %%
train[['item_id', 'artistId']].drop_duplicates()['item_id'].value_counts()
# Out:
# item_id
#  5070279068330501452    5
# -6467494677281402274    5
#  4481730207054338272    4
# -1355749385261276747    4
#  8527365250157953982    4
#                        ..
#  8312374410148845933    1
# -806689224870263072     1
#  3938851722130084185    1
# -7852283413896693105    1
#  2123071927435539666    1
# Name: count, Length: 629330, dtype: int64

# %%
item_features = DenseFeatures.from_dataframe(train[['item_id', 'artistId']].drop_duplicates(), id_col='item_id', id_map=idmap)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 item_features = DenseFeatures.from_dataframe(train[['item_id', 'artistId']].drop_duplicates(), id_col='item_id', id_map=idmap)
#
# File ~/ML/MLEnv/lib/python3.10/site-packages/rectools/dataset/features.py:117, in DenseFeatures.from_dataframe(cls, df, id_map, id_col)
#     115 df_ids = set(df[id_col].values)
#     116 if len(df_ids) != len(df):
# --> 117     raise ValueError("Ids in dataframe must be unique")
#     119 map_ids = set(id_map.external_ids)
#     120 if df_ids - map_ids:
#
# ValueError: Ids in dataframe must be unique

# %%
len(submission_users)
# Out:
# 388896

# %%
from surprise.prediction_algorithms import Prediction

# %%
train[Columns.Datetime] = 1

# %%
train[Columns.Weight] = 1

# %%
ds = Dataset.construct(train.drop(columns='artistId'))

# %%
ds
# Out:
# Dataset(user_id_map=IdMap(external_ids=array([-9223365420690745920, -9223357012432074795, -9223331337535253792,
#        ...,  9223341540783520542,  9223351321092564051,
#         9223371011342822842])), item_id_map=IdMap(external_ids=array(['4789011704403477758_4862000404086590321',
#        '-3685301030413601284_-5911062739952260612',
#        '-1040959798245656474_6738173673409941080', ...,
#        '-2931774007284753508_-4218997110618987591',
#        '-6245722852470884312_-1384941453457413172',
#        '2123071927435539666_-1384941453457413172'], dtype=object)), interactions=Interactions(df=         user_id  item_id  weight                      datetime
# 0              0        0     1.0 1970-01-01 00:00:00.000000001
# 1              1        1     1.0 1970-01-01 00:00:00.000000001
# 2              1        2     1.0 1970-01-01 00:00:00.000000001
# 3              2        3     1.0 1970-01-01 00:00:00.000000001
# 4              2        4     1.0 1970-01-01 00:00:00.000000001
# ...          ...      ...     ...                           ...
# 4920099  1166356     1793     1.0 1970-01-01 00:00:00.000000001
# 4920100  1166356    19697     1.0 1970-01-01 00:00:00.000000001
# 4920101  1166357     1738     1.0 1970-01-01 00:00:00.000000001
# 4920102  1166358      841     1.0 1970-01-01 00:00:00.000000001
# 4920103  1166359     3559     1.0 1970-01-01 00:00:00.000000001
#
# [4920104 rows x 4 columns]), user_features=None, item_features=None)

# %%
from rectools.models import LightFMWrapperModel
from lightfm import LightFM

model = LightFMWrapperModel(
        # внутри модели указываем параметр no_components
        # это размезность эмбеддингов, которые выучит модель
        model=LightFM(no_components = 10, item_alpha=1)
        )
# Out:
# /home/xbar19/ML/MLEnv/lib/python3.10/site-packages/implicit/gpu/__init__.py:13: UserWarning: CUDA extension is built, but disabling GPU support because of 'Cuda Error: no CUDA-capable device is detected (/project/./implicit/gpu/utils.h:71)'
#   warnings.warn(

# %%
model.fit(ds)

# %%
sub = pd.read_csv('recsys_music_vk/submission.csv')
sub
# Out:
#                      userId     recommended_id_1     recommended_id_2  \
# 0      -9223331337535253792 -2227263297444998835 -4695036104375440069
# 1      -9223315435871723421 -2227263297444998835 -4695036104375440069
# 2      -9223312953116183861 -2227263297444998835 -4695036104375440069
# 3      -9223189477397287224 -2227263297444998835 -4695036104375440069
# 4      -9223099495950652905 -2227263297444998835 -4695036104375440069
# ...                     ...                  ...                  ...
# 388891  9223205520969697450 -2227263297444998835 -4695036104375440069
# 388892  9223233690124762843 -2227263297444998835 -4695036104375440069
# 388893  9223256937547721480 -2227263297444998835 -4695036104375440069
# 388894  9223293703257417871 -2227263297444998835 -4695036104375440069
# 388895  9223323429584020370 -2227263297444998835 -4695036104375440069
#
#            recommended_id_3
# 0      -8860367773155756475
# 1      -8860367773155756475
# 2      -8860367773155756475
# 3      -8860367773155756475
# 4      -8860367773155756475
# ...                     ...
# 388891 -8860367773155756475
# 388892 -8860367773155756475
# 388893 -8860367773155756475
# 388894 -8860367773155756475
# 388895 -8860367773155756475
#
# [388896 rows x 4 columns]

# %%
recs = model.recommend(users=sub['userId'].unique(),
                       dataset=ds, 
                       k=3, filter_viewed=True)

# %%
recs.loc[recs['rank'] == 2, 'item_id'].value_counts()
# Out:
# item_id
# 2957260132109383577_-3200592824099817597     221790
# 7200408697552426542_-1820520629703737542     167027
# -6483949695788118226_-4335273471619998413        12
# 2248023499283390095_-2092946365572069367          9
# 7173417807261608128_-8250830488160323337          7
# -77588350185074450_-1238516356316409863           5
# 7784327918925939019_3271291963079767286           5
# 5207811820975355724_-8012373155940195240          4
# 8172706905504809477_-881523960919551605           4
# -8959801802950779801_6758737809529525644          4
# -8020190406615945128_-5585260879725572941         3
# 1521957696872268582_-5999388932388518213          3
# -441802527107339623_-1166204734664754196          2
# 2822072713254465645_3720242214155296729           2
# -7579097815205358934_-8952756520606106828         2
# -8763062237036787703_-7494663662323819446         2
# -379663161176396764_8867807711981221634           1
# 6968241575079683196_-6764623431090898875          1
# 2159321784421463369_-5951134964865843780          1
# 5020539487846029595_-4608113756303322231          1
# 3821283547694041144_733649550805317307            1
# -7091245282420775697_-3203249442068057552         1
# 2509952360005167174_6430413640089748666           1
# -4434608498776032978_2051084851707779665          1
# 7394184949180479843_7282062350625886887           1
# 8197857549631985472_855186444260057415            1
# -3631753548586798522_-7416402606990504532         1
# 7261541106732154859_-263813660333436678           1
# 7965387068237187893_-7910253975178598909          1
# -4042348512542527886_7014223527396022277          1
# 4814137432221348806_-3230120410277411448          1
# Name: count, dtype: int64

# %%
recs.loc[recs['rank'] == 3, 'item_id'].value_counts()
# Out:
# item_id
# 7200408697552426542_-1820520629703737542     221797
# 2957260132109383577_-3200592824099817597     167031
# 2248023499283390095_-2092946365572069367          6
# -6483949695788118226_-4335273471619998413         5
# 7173417807261608128_-8250830488160323337          5
# 2509952360005167174_6430413640089748666           4
# -8959801802950779801_6758737809529525644          4
# -4515975528852520966_-4488560309806482897         4
# 7653157716566687317_1397082796315862019           3
# -4434608498776032978_2051084851707779665          3
# -441802527107339623_-1166204734664754196          2
# 930151347829982872_569336915767488415             2
# -2632380308348811469_-7165433957338165203         2
# -815369767266630179_1413612511491545561           2
# 7784327918925939019_3271291963079767286           2
# 6968241575079683196_-6764623431090898875          2
# 1521957696872268582_-5999388932388518213          1
# -6586756604999748916_-4481147419298292872         1
# 5294160809619344104_4561115434137379568           1
# 7207857766141439519_8768573548160785132           1
# 2822072713254465645_3720242214155296729           1
# 3946835939325019617_-8128067202725708364          1
# -3631753548586798522_-7416402606990504532         1
# 5020539487846029595_-4608113756303322231          1
# -4180417908812703123_3855225508362158596          1
# 2134907645856116253_-7656260965250671258          1
# 7394184949180479843_7282062350625886887           1
# -7093194424657617229_79333131516560804            1
# 8197857549631985472_855186444260057415            1
# 8172706905504809477_-881523960919551605           1
# -4042348512542527886_7014223527396022277          1
# -6811322528489780539_-7950621782631124770         1
# -3469178458173036569_3855225508362158596          1
# -2952724785087063631_-7950621782631124770         1
# 3821283547694041144_733649550805317307            1
# 2978673247153210072_8533382419164054136           1
# -8075949787681341979_2016166303369409015          1
# 4814137432221348806_-3230120410277411448          1
# Name: count, dtype: int64

# %%
def inference(user):
    preds = recs[recs['user_id'] == user]
    p = []
    for i in range(1, 4):
        p.append(int(preds.loc[preds['rank'] == i, 'item_id'].item().split('_')[0]))
    return p

# %%
sub[[f'recommended_id_{i}' for i in range(1, 4)]] = sub['userId'].apply(inference)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_194454/1554293324.py in ?()
# ----> 1 sub[[f'recommended_id_{i}' for i in range(1, 4)]] = sub['userId'].apply(inference)
#
# ~/ML/MLEnv/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4295
#    4296         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
#    4301             self._set_item_frame_value(key, value)
#    4302         elif (
#
# ~/ML/MLEnv/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4354                 value = DataFrame(value).values
#    4355                 return self._setitem_array(key, value)
#    4356
#    4357             else:
# -> 4358                 self._iset_not_inplace(key, value)
#
# ~/ML/MLEnv/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4373                 return obj[i]
#    4374
#    4375         if self.columns.is_unique:
#    4376             if np.shape(value)[-1] != len(key):
# -> 4377                 raise ValueError("Columns must be same length as key")
#    4378
#    4379             for i, col in enumerate(key):
#    4380                 self[col] = igetitem(value, i)
#
# ValueError: Columns must be same length as key

# %%
sub[[f'recommended_id_{i}' for i in range(1, 4)]] = None

# %%
sub
# Out:
#                      userId      recommended_id_1      recommended_id_2  \
# 0      -9223331337535253792  -2227263297444998835  -8860367773155756475
# 1      -9223315435871723421  -2227263297444998835  -8860367773155756475
# 2      -9223312953116183861  -2227263297444998835  -8860367773155756475
# 3      -9223189477397287224  -2227263297444998835  -8860367773155756475
# 4      -9223099495950652905  -2227263297444998835  -8860367773155756475
# ...                     ...                   ...                   ...
# 388891  9223205520969697450                  None                  None
# 388892  9223233690124762843                  None                  None
# 388893  9223256937547721480                  None                  None
# 388894  9223293703257417871                  None                  None
# 388895  9223323429584020370                  None                  None
#
#             recommended_id_3
# 0       -4695036104375440069
# 1       -4695036104375440069
# 2       -4695036104375440069
# 3       -4695036104375440069
# 4       -4695036104375440069
# ...                      ...
# 388891                  None
# 388892                  None
# 388893                  None
# 388894                  None
# 388895                  None
#
# [388896 rows x 4 columns]

# %%
preds
# Out:
#                     user_id                                    item_id  \
# 132072 -6788780282756898784  -6483949695788118226_-4335273471619998413
# 132073 -6788780282756898784   7200408697552426542_-1820520629703737542
# 132074 -6788780282756898784   2957260132109383577_-3200592824099817597
#
#            score  rank
# 132072  0.067667     1
# 132073  0.067642     2
# 132074  0.067641     3

# %%
sub
# Out:
#                      userId     recommended_id_1     recommended_id_2  \
# 0      -9223331337535253792 -6483949695788118226  2957260132109383577
# 1      -9223315435871723421 -6483949695788118226  2957260132109383577
# 2      -9223312953116183861 -6483949695788118226  7200408697552426542
# 3      -9223189477397287224 -6483949695788118226  2957260132109383577
# 4      -9223099495950652905 -6483949695788118226  7200408697552426542
# ...                     ...                  ...                  ...
# 388891  9223205520969697450 -2227263297444998835 -4695036104375440069
# 388892  9223233690124762843 -2227263297444998835 -4695036104375440069
# 388893  9223256937547721480 -2227263297444998835 -4695036104375440069
# 388894  9223293703257417871 -2227263297444998835 -4695036104375440069
# 388895  9223323429584020370 -2227263297444998835 -4695036104375440069
#
#            recommended_id_3
# 0       7200408697552426542
# 1       7200408697552426542
# 2       2957260132109383577
# 3       7200408697552426542
# 4       2957260132109383577
# ...                     ...
# 388891 -8860367773155756475
# 388892 -8860367773155756475
# 388893 -8860367773155756475
# 388894 -8860367773155756475
# 388895 -8860367773155756475
#
# [388896 rows x 4 columns]

# %%
sub['recommended_id_1'] = recs.loc[recs['rank'] == 1, 'item_id'].values
sub['recommended_id_2'] = recs.loc[recs['rank'] == 2, 'item_id'].values
sub['recommended_id_3'] = recs.loc[recs['rank'] == 3, 'item_id'].values

# %%
sub
# Out:
#                      userId                           recommended_id_1  \
# 0      -9223331337535253792  -6483949695788118226_-4335273471619998413
# 1      -9223315435871723421  -6483949695788118226_-4335273471619998413
# 2      -9223312953116183861  -6483949695788118226_-4335273471619998413
# 3      -9223189477397287224  -6483949695788118226_-4335273471619998413
# 4      -9223099495950652905  -6483949695788118226_-4335273471619998413
# ...                     ...                                        ...
# 388891  9223205520969697450  -6483949695788118226_-4335273471619998413
# 388892  9223233690124762843  -6483949695788118226_-4335273471619998413
# 388893  9223256937547721480  -6483949695788118226_-4335273471619998413
# 388894  9223293703257417871  -6483949695788118226_-4335273471619998413
# 388895  9223323429584020370  -6483949695788118226_-4335273471619998413
#
#                                 recommended_id_2  \
# 0       2957260132109383577_-3200592824099817597
# 1       7200408697552426542_-1820520629703737542
# 2       7200408697552426542_-1820520629703737542
# 3       7200408697552426542_-1820520629703737542
# 4       2957260132109383577_-3200592824099817597
# ...                                          ...
# 388891  2957260132109383577_-3200592824099817597
# 388892  2957260132109383577_-3200592824099817597
# 388893  2957260132109383577_-3200592824099817597
# 388894  2957260132109383577_-3200592824099817597
# 388895  2957260132109383577_-3200592824099817597
#
#                                 recommended_id_3
# 0       7200408697552426542_-1820520629703737542
# 1       2957260132109383577_-3200592824099817597
# 2       2957260132109383577_-3200592824099817597
# 3       2957260132109383577_-3200592824099817597
# 4       7200408697552426542_-1820520629703737542
# ...                                          ...
# 388891  7200408697552426542_-1820520629703737542
# 388892  7200408697552426542_-1820520629703737542
# 388893  7200408697552426542_-1820520629703737542
# 388894  7200408697552426542_-1820520629703737542
# 388895  7200408697552426542_-1820520629703737542
#
# [388896 rows x 4 columns]

# %%
sub['recommended_id_1'] = sub['recommended_id_1'].str.split('_').apply(lambda x: x[0])
# Out:
# 0         -6483949695788118226
# 1         -6483949695788118226
# 2         -6483949695788118226
# 3         -6483949695788118226
# 4         -6483949695788118226
#                   ...
# 388891    -6483949695788118226
# 388892    -6483949695788118226
# 388893    -6483949695788118226
# 388894    -6483949695788118226
# 388895    -6483949695788118226
# Name: recommended_id_1, Length: 388896, dtype: object

# %%
recs.loc[recs['rank'] == 1, ]
# Out:
#                      user_id                                    item_id  \
# 0       -9223331337535253792  -6483949695788118226_-4335273471619998413
# 3       -9223312953116183861  -6483949695788118226_-4335273471619998413
# 6       -9223099495950652905  -6483949695788118226_-4335273471619998413
# 9       -9222957206048518287  -6483949695788118226_-4335273471619998413
# 12      -9222870482588617996  -6483949695788118226_-4335273471619998413
# ...                      ...                                        ...
# 1166673  9222233924659284930  -6483949695788118226_-4335273471619998413
# 1166676  9222344996066051590  -6483949695788118226_-4335273471619998413
# 1166679  9222512814920300906  -6483949695788118226_-4335273471619998413
# 1166682  9222609400741559907  -6483949695788118226_-4335273471619998413
# 1166685  9223256937547721480  -6483949695788118226_-4335273471619998413
#
#             score  rank
# 0        0.047694     1
# 3        0.187984     1
# 6        0.086028     1
# 9        0.047699     1
# 12       0.025611     1
# ...           ...   ...
# 1166673  0.000614     1
# 1166676  0.000614     1
# 1166679  0.000614     1
# 1166682  0.000614     1
# 1166685  0.000614     1
#
# [388896 rows x 4 columns]

# %%
for user in tqdm(sub['userId'].unique()):
    preds = recs[recs['user_id'] == user]
    for i in range(1, 4):
        sub.loc[sub['userId'] == user, f'recommended_id_{i}'] = int(preds.loc[preds['rank'] == i, 'item_id'].item().split('_')[0])
# Out:
#  13%|██████████████                                                                                            | 51416/388896 [04:02<26:31, 212.05it/s]
#
# KeyboardInterrupt

# %%
pd.read_csv('recsys_music_vk/submission.csv')
# Out:
#                      userId     recommended_id_1     recommended_id_2  \
# 0      -9223331337535253792 -2227263297444998835 -4695036104375440069
# 1      -9223315435871723421 -2227263297444998835 -4695036104375440069
# 2      -9223312953116183861 -2227263297444998835 -4695036104375440069
# 3      -9223189477397287224 -2227263297444998835 -4695036104375440069
# 4      -9223099495950652905 -2227263297444998835 -4695036104375440069
# ...                     ...                  ...                  ...
# 388891  9223205520969697450 -2227263297444998835 -4695036104375440069
# 388892  9223233690124762843 -2227263297444998835 -4695036104375440069
# 388893  9223256937547721480 -2227263297444998835 -4695036104375440069
# 388894  9223293703257417871 -2227263297444998835 -4695036104375440069
# 388895  9223323429584020370 -2227263297444998835 -4695036104375440069
#
#            recommended_id_3
# 0      -8860367773155756475
# 1      -8860367773155756475
# 2      -8860367773155756475
# 3      -8860367773155756475
# 4      -8860367773155756475
# ...                     ...
# 388891 -8860367773155756475
# 388892 -8860367773155756475
# 388893 -8860367773155756475
# 388894 -8860367773155756475
# 388895 -8860367773155756475
#
# [388896 rows x 4 columns]

# %%
sub
# Out:
#                      userId      recommended_id_1      recommended_id_2  \
# 0      -9223331337535253792  -2227263297444998835  -8860367773155756475
# 1      -9223315435871723421  -2227263297444998835  -8860367773155756475
# 2      -9223312953116183861  -2227263297444998835  -8860367773155756475
# 3      -9223189477397287224  -2227263297444998835  -8860367773155756475
# 4      -9223099495950652905  -2227263297444998835  -8860367773155756475
# ...                     ...                   ...                   ...
# 388891  9223205520969697450  -2227263297444998835  -8860367773155756475
# 388892  9223233690124762843  -2227263297444998835  -8860367773155756475
# 388893  9223256937547721480  -2227263297444998835  -8860367773155756475
# 388894  9223293703257417871  -2227263297444998835  -8860367773155756475
# 388895  9223323429584020370  -2227263297444998835  -8860367773155756475
#
#             recommended_id_3
# 0       -4695036104375440069
# 1       -4695036104375440069
# 2       -4695036104375440069
# 3       -4695036104375440069
# 4       -4695036104375440069
# ...                      ...
# 388891  -4695036104375440069
# 388892  -4695036104375440069
# 388893  -4695036104375440069
# 388894  -4695036104375440069
# 388895  -4695036104375440069
#
# [388896 rows x 4 columns]

# %%
sub.to_csv('recsys_music_vk/submissions/lfm.csv', index=False)

# %%
recs
# Out:
#                      user_id                                    item_id  \
# 0       -9223331337535253792   -2227263297444998835_3978571263572442387
# 1       -9223331337535253792   -8860367773155756475_3181968405932737874
# 2       -9223331337535253792  -4695036104375440069_-1317879221316914278
# 3       -9223312953116183861   -2227263297444998835_3978571263572442387
# 4       -9223312953116183861   -8860367773155756475_3181968405932737874
# ...                      ...                                        ...
# 1166683  9222609400741559907   -8860367773155756475_3181968405932737874
# 1166684  9222609400741559907  -4695036104375440069_-1317879221316914278
# 1166685  9223256937547721480   -2227263297444998835_3978571263572442387
# 1166686  9223256937547721480   -8860367773155756475_3181968405932737874
# 1166687  9223256937547721480  -4695036104375440069_-1317879221316914278
#
#             score  rank
# 0        4.335444     1
# 1        4.321002     2
# 2        4.266007     3
# 3        4.474041     1
# 4        4.461549     2
# ...           ...   ...
# 1166683  4.296211     2
# 1166684  4.241176     3
# 1166685  4.310917     1
# 1166686  4.296211     2
# 1166687  4.241176     3
#
# [1166688 rows x 4 columns]

# %%
model.predict()
# Out:
# 5

# %%
# submission_users = user_encoder.transform(submission_users)  # Кодируем userId

# Генерация рекомендаций для каждого пользователя
recommendations = []
for user in tqdm(submission_users):
    recommended_tracks = get_top_n_recommendations(user, n=3)
    # Декодируем id треков обратно в исходный формат
    recommended_tracks = track_encoder.inverse_transform(recommended_tracks)
    recommendations.append([user_encoder.inverse_transform([user])[0]] + list(recommended_tracks))
# Out:
#   0%|                                                                                                                       | 0/388896 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 6
#       4 recommendations = []
#       5 for user in tqdm(submission_users):
# ----> 6     recommended_tracks = get_top_n_recommendations(user, n=3)
#       7     # Декодируем id треков обратно в исходный формат
#       8     recommended_tracks = track_encoder.inverse_transform(recommended_tracks)
#
# Cell In[46], line 5, in get_top_n_recommendations(user_id, n)
#       3 all_tracks = data['id'].unique()
#       4 # Предсказываем рейтинги для всех треков
# ----> 5 scores = model.predict(user_id, all_tracks, item_features=item_features)
#       6 # Сортируем треки по убыванию рейтинга
#       7 top_tracks = all_tracks[np.argsort(-scores)]
#
# File ~/ML/MLEnv/lib/python3.10/site-packages/lightfm/lightfm.py:830, in LightFM.predict(self, user_ids, item_ids, item_features, user_features, num_threads)
#     827 if isinstance(item_ids, (list, tuple)):
#     828     item_ids = np.array(item_ids, dtype=np.int32)
# --> 830 if len(user_ids) != len(item_ids):
#     831     raise ValueError(
#     832         f"Expected the number of user IDs ({len(user_ids)}) to equal the number"
#     833         f" of item IDs ({len(item_ids)})"
#     834     )
#     836 if user_ids.dtype != np.int32:
#
# TypeError: object of type 'numpy.int64' has no len()

# %%
train
# Out:
#           userId      id  artistId  rating
# 0              0  477925    108357       1
# 1              1  189097     25598       1
# 2              1  279382    122729       1
# 3              2   16063     51457       1
# 4              2  565644     68717       1
# ...          ...     ...       ...     ...
# 4920099  1166356   77050     41053       1
# 4920100  1166356  441231     42657       1
# 4920101  1166357  598218     16233       1
# 4920102  1166358  209331    114256       1
# 4920103  1166359  110740     83076       1
#
# [4920104 rows x 4 columns]

# %%
cross_validate
